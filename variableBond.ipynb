# %%
import json
from pathlib import Path
import numpy as np
import pandas as pd
#import openaml_importer.model as models

# %%
with open("data/assets.json", "r") as f:
    data = json.load(f)

# %%
type(data)
# Out:
# dict

# %%
dd = data['assets']

# %%
typeAsset='VARIABLE_BOND'

# %%
# list of Variables bonds
pd.set_option('display.max_rows', 300)
indexlist = []
col=['maturityDate', 'quotationdate', 'quotationvalue', 'currency', 'group', 'collateralType','callable', 'hybrid', 
     'inflationIndexed', 'index', 'marginadd', 'rateType','couponType'] #, 'index'
pdswap = pd.DataFrame(columns=col)
j=0
for i in range(len(dd)):
    if ((dd[i]['assetType']== typeAsset) and (dd[i]['interestRate'].get('index') != None)):
        #print('tt',dd[i]['interestRate'].get('index'))
        pdnew=pd.DataFrame([[dd[i]['maturityDate'],
                             dd[i]['quotations'][0]['date'],
                             dd[i]['quotations'][0]['close'],
                             dd[i]['ccy'], 
                             dd[i]['assetGroup'],
                             dd[i].get('collateralType'), 
                             dd[i]['callable'], 
                             dd[i]['hybrid'], 
                             dd[i]['inflationIndexed'], 
                             dd[i]['interestRate']['index']['_id'], 
                             dd[i]['interestRate']['marginAdd'], 
                             dd[i]['interestRate']['rateType'], 
                             dd[i]['interestRate']['couponType'],                        
        #dd[i]['legs'][0]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][0]['interest']['dayCountMethod'], 
                             #dd[i]['legs'][0]['interest']['index']['_id'], 
                             #dd[i]['legs'][1]['side'], 
                             #dd[i]['legs'][1]['interest']['rateType'], 
                             #dd[i]['legs'][1]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][1]['interest']['dayCountMethod'],
                             #dd[i]['legs'][1]['interest'].get('rate')
                            ]], 
                             columns=col, index=[dd[i]['name']])
        indexlist.append(dd[i]['interestRate']['index']['_id'])
        pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
display(pdswap)
# Out:
# /tmp/ipykernel_17520/410079999.py:35: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
#                       maturityDate quotationdate  quotationvalue currency  \
# NAB FRN 05/25 REGS      2025-05-13    2024-12-19      100.219000      USD
# TOYOTA FRN 04/26 EMTN   2026-04-30    2024-12-19      100.170000      EUR
# NACN FRN 06/25 EMTN     2025-06-13    2024-12-19      100.197000      EUR
# GIS FRN 10/26           2026-10-22    2024-12-19      100.333000      EUR
# CM FRN 10/26 EMTN       2026-10-30    2024-12-19       99.971000      EUR
# BNS FRN 09/25 EMTN      2025-09-22    2024-12-19      100.295000      EUR
# TF FRN 01/25            2025-01-31    2024-12-19      100.011613      USD
# TD FRN 01/25 EMTN       2025-01-20    2024-12-19      100.051000      EUR
# SOCGEN FRN 01/25 EMT5   2025-01-31    2024-12-13      100.059738      EUR
# BACRED FRN 03/26 EMTN   2026-03-08    2024-12-19      100.022000      EUR
# TF FRN 10/25            2025-10-31    2024-12-19      100.042550      USD
# ABNANV FRN 09/25 EMTN   2025-09-22    2024-12-19      100.170000      EUR
# BERTEL FRN 07/26 EMTN   2026-07-17    2024-12-19      100.109000      EUR
# SOCGEN FRN 01/25 EMTN   2025-01-13    2024-12-19      100.033000      EUR
# DSVDC FRN 11/26 EMTN    2026-11-06    2024-12-19      100.316000      EUR
# TOYOTA FRN 12/24 EMTN   2024-12-23    2024-12-19      100.000000      EUR
# NAB FRN 01/25 144A      2025-01-12    2024-12-19      100.011000      USD
# ROSW FRN 03/25 144A     2025-03-10    2024-12-19      100.281000      USD
# HNDA FRN 05/26 EMTN     2026-05-29    2024-12-19      100.047000      EUR
# CM FRN 03/26            2026-03-27    2024-12-19      100.163000      EUR
# SOCGEN FRN 01/26 EMTN   2026-01-19    2024-12-19      100.289000      EUR
# HNDA FRN 04/26          2026-04-29    2024-12-19      100.068000      EUR
# BNS FRN 12/25 EMTN      2025-12-12    2024-12-19      100.281000      EUR
# TOYOTA FRN 01/26 EMTN   2026-01-07    2024-12-19      100.104000      EUR
# VLVY FRN 01/26 EMTN     2026-01-09    2024-12-19      100.253000      EUR
# BMO FRN 09/25 EMTN      2025-09-05    2024-12-19      100.207000      EUR
# TF FRN 01/26            2026-01-31    2024-12-19      100.138115      USD
# CADEPO FRN 05/25 REGS   2025-05-19    2024-12-19      100.105000      USD
# PSPCAP FRN 03/25 REGS   2025-03-03    2024-12-19      100.024000      USD
# BNS FRN 05/25 EMTN      2025-05-02    2024-12-19      100.138000      EUR
# BMO FRN 06/25 EMTN      2025-06-06    2024-12-19      100.146000      EUR
# BNS FRN 03/26 EMTN      2026-03-26    2024-12-19      100.161000      EUR
# ACAFP FRN 03/25 EMTN    2025-03-07    2024-12-19      100.064000      EUR
# AYVFP FRN 10/25 EMTN    2025-10-06    2024-12-19      100.348000      EUR
# TF FRN 07/25            2025-07-31    2024-12-19      100.010511      USD
# BNP FRN 02/25 EMTN      2025-02-24    2024-12-19      100.064000      EUR
# BNS FRN 06/26 EMTN      2026-06-17    2024-12-19      100.132000      EUR
# VLVY FRN 05/26 EMTN     2026-05-22    2024-12-19      100.078000      EUR
# AT&T FRN 03/25          2025-03-06    2024-12-19      100.069000      EUR
# SANTAN FRN 01/25 EMTN   2025-01-16    2024-12-19      100.060000      EUR
# AYVFP FRN 02/25 EMTN    2025-02-21    2024-12-19      100.100000      EUR
# NACN FRN 03/26 EMTN     2026-03-06    2024-12-19      100.191000      EUR
# GIS FRN 04/26           2026-04-22    2024-12-19      100.052000      EUR
# TOYOTA FRN 03/26 EMTN   2026-03-13    2024-12-19      100.167000      EUR
# KBC FRN 03/26 EMTN      2026-03-04    2024-12-19      100.116000      EUR
# CM FRN 01/27 EMTN       2027-01-29    2024-12-19      100.569000      EUR
# SEB FRN 06/25 GMTN      2025-06-13    2024-12-19      100.176000      EUR
# TF FRN 04/25            2025-04-30    2024-12-19      100.034984      USD
# VLVY FRN 11/25 EMTN     2025-11-21    2024-12-19      100.288000      EUR
# TD FRN 07/25 GMTN       2025-07-21    2024-12-19      100.206000      EUR
#
#                             group   collateralType callable hybrid  \
# NAB FRN 05/25 REGS      CORPORATE     SR UNSECURED    False  False
# TOYOTA FRN 04/26 EMTN   CORPORATE     SR UNSECURED    False  False
# NACN FRN 06/25 EMTN     CORPORATE     SR UNSECURED    False  False
# GIS FRN 10/26           CORPORATE     SR UNSECURED    False  False
# CM FRN 10/26 EMTN       CORPORATE     SR UNSECURED    False  False
# BNS FRN 09/25 EMTN      CORPORATE     SR UNSECURED    False  False
# TF FRN 01/25           GOVERNMENT             None    False  False
# TD FRN 01/25 EMTN       CORPORATE     SR UNSECURED    False  False
# SOCGEN FRN 01/25 EMT5   CORPORATE             None    False  False
# BACRED FRN 03/26 EMTN   CORPORATE     SR PREFERRED     True  False
# TF FRN 10/25           GOVERNMENT             None    False  False
# ABNANV FRN 09/25 EMTN   CORPORATE     SR PREFERRED    False  False
# BERTEL FRN 07/26 EMTN   CORPORATE     SR UNSECURED     True  False
# SOCGEN FRN 01/25 EMTN   CORPORATE     SR PREFERRED    False  False
# DSVDC FRN 11/26 EMTN    CORPORATE   COMPANY GUARNT    False  False
# TOYOTA FRN 12/24 EMTN   CORPORATE     SR UNSECURED    False  False
# NAB FRN 01/25 144A      CORPORATE     SR UNSECURED    False  False
# ROSW FRN 03/25 144A     CORPORATE   COMPANY GUARNT    False  False
# HNDA FRN 05/26 EMTN     CORPORATE        UNSECURED    False  False
# CM FRN 03/26            CORPORATE     SR UNSECURED    False  False
# SOCGEN FRN 01/26 EMTN   CORPORATE     SR PREFERRED    False  False
# HNDA FRN 04/26          CORPORATE     SR UNSECURED    False  False
# BNS FRN 12/25 EMTN      CORPORATE     SR UNSECURED    False  False
# TOYOTA FRN 01/26 EMTN   CORPORATE     SR UNSECURED    False  False
# VLVY FRN 01/26 EMTN     CORPORATE   COMPANY GUARNT    False  False
# BMO FRN 09/25 EMTN      CORPORATE     SR UNSECURED    False  False
# TF FRN 01/26           GOVERNMENT             None    False  False
# CADEPO FRN 05/25 REGS  GOVERNMENT   COMPANY GUARNT    False  False
# PSPCAP FRN 03/25 REGS  GOVERNMENT   COMPANY GUARNT    False  False
# BNS FRN 05/25 EMTN      CORPORATE     SR UNSECURED    False  False
# BMO FRN 06/25 EMTN      CORPORATE     SR UNSECURED    False  False
# BNS FRN 03/26 EMTN      CORPORATE     SR UNSECURED    False  False
# ACAFP FRN 03/25 EMTN    CORPORATE     SR PREFERRED    False  False
# AYVFP FRN 10/25 EMTN    CORPORATE     SR PREFERRED    False  False
# TF FRN 07/25           GOVERNMENT             None    False  False
# BNP FRN 02/25 EMTN      CORPORATE     SR PREFERRED    False  False
# BNS FRN 06/26 EMTN      CORPORATE     SR UNSECURED    False  False
# VLVY FRN 05/26 EMTN     CORPORATE   COMPANY GUARNT    False  False
# AT&T FRN 03/25          CORPORATE     SR UNSECURED    False  False
# SANTAN FRN 01/25 EMTN   CORPORATE     SR PREFERRED    False  False
# AYVFP FRN 02/25 EMTN    CORPORATE     SR UNSECURED    False  False
# NACN FRN 03/26 EMTN     CORPORATE     SR UNSECURED    False  False
# GIS FRN 04/26           CORPORATE     SR UNSECURED    False  False
# TOYOTA FRN 03/26 EMTN   CORPORATE     SR UNSECURED    False  False
# KBC FRN 03/26 EMTN      CORPORATE  BANK GUARANTEED    False  False
# CM FRN 01/27 EMTN       CORPORATE     SR UNSECURED    False  False
# SEB FRN 06/25 GMTN      CORPORATE     SR PREFERRED    False  False
# TF FRN 04/25           GOVERNMENT             None    False  False
# VLVY FRN 11/25 EMTN     CORPORATE   COMPANY GUARNT    False  False
# TD FRN 07/25 GMTN       CORPORATE     SR UNSECURED    False  False
#
#                       inflationIndexed     index  marginadd  rateType  \
# NAB FRN 05/25 REGS               False   5967593      0.760  FLOATING
# TOYOTA FRN 04/26 EMTN            False    251374      0.400     RESET
# NACN FRN 06/25 EMTN              False    251374      0.550     RESET
# GIS FRN 10/26                    False    251374      0.600     RESET
# CM FRN 10/26 EMTN                False    251374      0.450     RESET
# BNS FRN 09/25 EMTN               False    251374      0.500     RESET
# TF FRN 01/25                     False  11248921      0.200     RESET
# TD FRN 01/25 EMTN                False    251374      0.450     RESET
# SOCGEN FRN 01/25 EMT5            False   6741831      0.415  FLOATING
# BACRED FRN 03/26 EMTN            False    251374      0.400     RESET
# TF FRN 10/25                     False  11248921      0.170     RESET
# ABNANV FRN 09/25 EMTN            False    251374      0.380     RESET
# BERTEL FRN 07/26 EMTN            False    251374      0.530     RESET
# SOCGEN FRN 01/25 EMTN            False    251374      0.450     RESET
# DSVDC FRN 11/26 EMTN             False    251374      0.500     RESET
# TOYOTA FRN 12/24 EMTN            False    251374      0.280     RESET
# NAB FRN 01/25 144A               False   5967593      0.380  FLOATING
# ROSW FRN 03/25 144A              False   5967593      0.560  FLOATING
# HNDA FRN 05/26 EMTN              False    251374      0.420     RESET
# CM FRN 03/26                     False    251374      0.400     RESET
# SOCGEN FRN 01/26 EMTN            False    251374      0.500     RESET
# HNDA FRN 04/26                   False    251374      0.380     RESET
# BNS FRN 12/25 EMTN               False    251374      0.520     RESET
# TOYOTA FRN 01/26 EMTN            False    251374      0.360     RESET
# VLVY FRN 01/26 EMTN              False    251374      0.500     RESET
# BMO FRN 09/25 EMTN               False    251374      0.470     RESET
# TF FRN 01/26                     False  11248921      0.245     RESET
# CADEPO FRN 05/25 REGS            False   8764803      0.400  FLOATING
# PSPCAP FRN 03/25 REGS            False   8764803      0.240     RESET
# BNS FRN 05/25 EMTN               False    251374      0.430     RESET
# BMO FRN 06/25 EMTN               False    251374      0.450     RESET
# BNS FRN 03/26 EMTN               False    251374      0.400     RESET
# ACAFP FRN 03/25 EMTN             False    251374      0.320     RESET
# AYVFP FRN 10/25 EMTN             False    251374      0.650     RESET
# TF FRN 07/25                     False  11248921      0.125     RESET
# BNP FRN 02/25 EMTN               False    251374      0.300     RESET
# BNS FRN 06/26 EMTN               False    251374      0.400     RESET
# VLVY FRN 05/26 EMTN              False    251374      0.380     RESET
# AT&T FRN 03/25                   False    251374      0.400     RESET
# SANTAN FRN 01/25 EMTN            False    251374      0.550     RESET
# AYVFP FRN 02/25 EMTN             False    251374      0.550     RESET
# NACN FRN 03/26 EMTN              False    251374      0.450     RESET
# GIS FRN 04/26                    False    251374      0.500     RESET
# TOYOTA FRN 03/26 EMTN            False    251374      0.400     RESET
# KBC FRN 03/26 EMTN               False    251374      0.350     RESET
# CM FRN 01/27 EMTN                False    251374      0.700     RESET
# SEB FRN 06/25 GMTN               False    251374      0.450     RESET
# TF FRN 04/25                     False  11248921      0.169     RESET
# VLVY FRN 11/25 EMTN              False    251374      0.550     RESET
# TD FRN 07/25 GMTN                False    251374      0.450     RESET
#
#                       couponType
# NAB FRN 05/25 REGS      FLOATING
# TOYOTA FRN 04/26 EMTN   FLOATING
# NACN FRN 06/25 EMTN     FLOATING
# GIS FRN 10/26           FLOATING
# CM FRN 10/26 EMTN       FLOATING
# BNS FRN 09/25 EMTN      FLOATING
# TF FRN 01/25            FLOATING
# TD FRN 01/25 EMTN       FLOATING
# SOCGEN FRN 01/25 EMT5   FLOATING
# BACRED FRN 03/26 EMTN   FLOATING
# TF FRN 10/25            FLOATING
# ABNANV FRN 09/25 EMTN   FLOATING
# BERTEL FRN 07/26 EMTN   FLOATING
# SOCGEN FRN 01/25 EMTN   FLOATING
# DSVDC FRN 11/26 EMTN    FLOATING
# TOYOTA FRN 12/24 EMTN   FLOATING
# NAB FRN 01/25 144A      FLOATING
# ROSW FRN 03/25 144A     FLOATING
# HNDA FRN 05/26 EMTN     FLOATING
# CM FRN 03/26            FLOATING
# SOCGEN FRN 01/26 EMTN   FLOATING
# HNDA FRN 04/26          FLOATING
# BNS FRN 12/25 EMTN      FLOATING
# TOYOTA FRN 01/26 EMTN   FLOATING
# VLVY FRN 01/26 EMTN     FLOATING
# BMO FRN 09/25 EMTN      FLOATING
# TF FRN 01/26            FLOATING
# CADEPO FRN 05/25 REGS   FLOATING
# PSPCAP FRN 03/25 REGS   FLOATING
# BNS FRN 05/25 EMTN      FLOATING
# BMO FRN 06/25 EMTN      FLOATING
# BNS FRN 03/26 EMTN      FLOATING
# ACAFP FRN 03/25 EMTN    FLOATING
# AYVFP FRN 10/25 EMTN    FLOATING
# TF FRN 07/25            FLOATING
# BNP FRN 02/25 EMTN      FLOATING
# BNS FRN 06/26 EMTN      FLOATING
# VLVY FRN 05/26 EMTN     FLOATING
# AT&T FRN 03/25          FLOATING
# SANTAN FRN 01/25 EMTN   FLOATING
# AYVFP FRN 02/25 EMTN    FLOATING
# NACN FRN 03/26 EMTN     FLOATING
# GIS FRN 04/26           FLOATING
# TOYOTA FRN 03/26 EMTN   FLOATING
# KBC FRN 03/26 EMTN      FLOATING
# CM FRN 01/27 EMTN       FLOATING
# SEB FRN 06/25 GMTN      FLOATING
# TF FRN 04/25            FLOATING
# VLVY FRN 11/25 EMTN     FLOATING
# TD FRN 07/25 GMTN       FLOATING

# %%
indexlist = set(indexlist)
indexlist
# Out:
# {'11248921', '251374', '5967593', '6741831', '8764803'}

# %%
# index
j=0
col=['index' , 'assetType',   'currency', 'rateType'] 
#col=['maturityDate', 'side0', 'ratetype', 'frequency', 'daycountmethod' ,'index','ratetype1','frequency', 'daycountmethod', 'rate'] #

pdswap = pd.DataFrame(columns=col)
for i in range(len(dd)):
    if ((dd[i].get('_id') in indexlist)):
        j=j+1
        pdnew=pd.DataFrame([[dd[i]['_id'],
                             dd[i]['assetType'], 
                             #dd[i]['quotations'][0]['date'], 
                             #dd[i]['quotations'][0]['last'], 
                             dd[i]['ccy']
                             #dd[i]['legs'][0]['interest']['index']['_id'], 
                             #dd[i]['legs'][1]['side'], 
                             #dd[i]['legs'][1]['interest']['rateType'], 
                             #dd[i]['legs'][1]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][1]['interest']['dayCountMethod'],
                            ]], 
                             columns=col, index=[dd[i]['name']])        
        pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
        #print(dd[i])
print(j)
pdswap
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/github/swap/.venv/lib/python3.12/site-packages/pandas/core/internals/construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File ~/github/swap/.venv/lib/python3.12/site-packages/pandas/core/internals/construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 4 columns passed, passed data had 3 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 10
#       8 if ((dd[i].get('_id') in indexlist)):
#       9     j=j+1
# ---> 10     pdnew=pd.DataFrame([[dd[i]['_id'],
#      11                          dd[i]['assetType'],
#      12                          #dd[i]['quotations'][0]['date'],
#      13                          #dd[i]['quotations'][0]['last'],
#      14                          dd[i]['ccy']
#      15                          #dd[i]['legs'][0]['interest']['index']['_id'],
#      16                          #dd[i]['legs'][1]['side'],
#      17                          #dd[i]['legs'][1]['interest']['rateType'],
#      18                          #dd[i]['legs'][1]['interest']['paymentFrequency']['code'],
#      19                          #dd[i]['legs'][1]['interest']['dayCountMethod'],
#      20                         ]],
#      21                          columns=col, index=[dd[i]['name']])
#      22     pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
#      23     #print(dd[i])
#
# File ~/github/swap/.venv/lib/python3.12/site-packages/pandas/core/frame.py:851, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     849     if columns is not None:
#     850         columns = ensure_index(columns)
# --> 851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     854         data,
#     855         columns,
#     856         index,  # type: ignore[arg-type]
#     857         dtype,
#     858     )
#     859     mgr = arrays_to_mgr(
#     860         arrays,
#     861         columns,
#    (...)
#     864         typ=manager,
#     865     )
#     866 else:
#
# File ~/github/swap/.venv/lib/python3.12/site-packages/pandas/core/internals/construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File ~/github/swap/.venv/lib/python3.12/site-packages/pandas/core/internals/construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File ~/github/swap/.venv/lib/python3.12/site-packages/pandas/core/internals/construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 4 columns passed, passed data had 3 columns

# %%
# list of Variables bonds
pd.set_option('display.max_rows', 300)
col=['maturityDate', 'quotationdate', 'quotationvalue', 'currency', 'group', 'collateralType', 'hybrid', 'inflationIndexed'] #, 'index'
pdswap = pd.DataFrame(columns=col)
j=0
for i in range(len(dd)):
    if ((dd[i]['assetType']== typeAsset) and (dd[i]['interestRate'].get('index') == None)):
        #print('tt',dd[i]['interestRate'].get('index'))
        pdnew=pd.DataFrame([[dd[i]['maturityDate'],
                             dd[i]['quotations'][0]['date'],
                             dd[i]['quotations'][0]['close'],
                             dd[i]['ccy'], 
                             dd[i]['assetGroup'], 
                             dd[i]['collateralType'], 
                             dd[i]['hybrid'], 
                             dd[i]['inflationIndexed'], 
                             #dd[i]['interestRate']['index']['_id'], 
                             #dd[i]['interestRate']['marginAdd'], 
                             #dd[i]['legs'][0]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][0]['interest']['dayCountMethod'], 
                             #dd[i]['legs'][0]['interest']['index']['_id'], 
                             #dd[i]['legs'][1]['side'], 
                             #dd[i]['legs'][1]['interest']['rateType'], 
                             #dd[i]['legs'][1]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][1]['interest']['dayCountMethod'],
                             #dd[i]['legs'][1]['interest'].get('rate')
                            ]], 
                             columns=col, index=[dd[i]['name']])
        pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
display(pdswap)
