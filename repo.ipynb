# %%
import json
from pathlib import Path
from xsdata.formats.dataclass.parsers import XmlParser, JsonParser, DictDecoder
from xsdata.formats.dataclass.parsers.config import ParserConfig
from xsdata.formats.dataclass.context import XmlContext
import numpy as np
import pandas as pd
#import openaml_importer.model as models

# %%
with open("data/assets.json", "r") as f:
    data = json.load(f)

# %%
type(data)
# Out:
# dict

# %%
dd = data['assets']

# %% [markdown]
# # Le taux repo est dans le nom ?

# %%
# list of swaps ESTR
pd.set_option('display.max_rows', 300)
col=['maturityDate', 'startDate', 'ccy', 'nominal', 'counterparty name', 'counterparty id'] #
pdswap = pd.DataFrame(columns=col)
j=0
for i in range(len(dd)):
    if ((dd[i]['assetType']=='REPO')):
        #print('tt',dd[i]['legs'][0]['interest'].get('index'))
        pdnew=pd.DataFrame([[dd[i]['maturityDate'],
                             dd[i]['startDate'],
                             dd[i]['ccy'],
                             dd[i]['nominal'], 
                             dd[i]['counterparty']['name'], 
                             dd[i]['counterparty']['_id']
                            ]], 
                             columns=col, index=[dd[i]['name']])
        pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
display(pdswap)
# Out:
# /tmp/ipykernel_39698/1590769929.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
#                                          maturityDate   startDate  ccy  \
# FINLAND 0.5% 09/28 10Y                     2025-01-20  2024-11-18  EUR
# BTPS 1.6% 06/2026                          2025-02-11  2024-12-11  EUR
# OAT 3.50% 04/26                            2025-01-15  2024-11-15  EUR
# OAT 0.75% 05/53 OAT                        2025-01-10  2024-11-20  EUR
# SPAIN % 05/25                              2025-01-13  2024-11-11  EUR
# OAT I 0.1% 3/25 OATI                       2025-01-09  2024-12-06  EUR
# OAT 2.5% 5/30                              2025-01-15  2024-11-15  EUR
# BTPS IE 2.55% 09/41 BTPE                   2025-02-11  2024-12-11  EUR
# OBL 2.4% 10/28 188                         2025-01-20  2024-11-18  EUR
# WFC 1.625% 06/25                           2025-01-14  2024-11-14  EUR
# OAT IE 0.1% 03/29 OATE                     2025-01-07  2024-12-09  EUR
# OAT I 3.40% 25/07/29 OATI                  2025-01-09  2024-12-06  EUR
# SPAIN 0% STRIP 10/34                       2025-02-11  2024-12-11  EUR
# EU 4% 04/44 NGEU                           2025-01-09  2024-11-28  EUR
# EU 3.375% 10/39 NGEU                       2025-01-07  2024-11-21  EUR
# CAISSE FRANCAISE DE F 3.24% 19/02/29 EUR   2025-01-14  2024-11-14  EUR
# CAFFIL 3.5% 03/29 EMTN                     2025-01-20  2024-11-18  EUR
# EFSF 1.45% 9/40                            2025-01-07  2024-11-18  EUR
# OAT 0.75% 05/53 OAT                        2025-01-08  2024-12-04  EUR
# AUSTRIA 0.5% 02/29                         2025-01-20  2024-11-18  EUR
# OAT 0% 02/27                               2025-01-10  2024-11-12  EUR
# OAT 2.5% 09/27 OAT                         2025-01-16  2024-11-25  EUR
# BTPS 3.1% 08/26 2Y                         2025-01-09  2024-11-04  EUR
# OAT 0.75% 11/28 OAT                        2025-01-13  2024-11-15  EUR
# OAT IE 1.85% 07/27 OATE                    2025-01-07  2024-12-09  EUR
# OAT 0.75% 05/28                            2025-01-09  2024-12-06  EUR
# DBR % 08/50                               2.777500e+07
# EFSF 1.75% 07/53                          1.312954e+07
# EFSF 1.8% 07/48                           4.984920e+07
# EFSF 2% 2/56                              1.065636e+07
# BTPS 1.6% 06/2026                         1.999469e+06
# OAT 2.75% 02/30 OAT                       1.020400e+08
# US TII 0.375% 7/25                        6.585000e+07
# BTPS IE 0.4% 05/30 BTPE                   2.435399e+06
# BTP STRIP 01/08/33                        1.998771e+06
# BTPS IE 2.55% 09/41 BTPE                  2.735847e+06
# DBR 2.3% 02/33                            1.012000e+08
# BELGIUM 1% 06/26                          4.920500e+07
# OAT I 0.1% 03/28 OATI                     3.280000e+07
# SPAIN 0% STRIP 10/29                      1.999404e+06
# OAT 6% 94-10/25                           2.080000e+07
# OAT 0.75% 05/28                           1.414950e+08
# NEDERLD 0.75% 07/28                       4.748500e+07
# OAT I 3.40% 25/07/29 OATI                 3.400000e+07
# OAT IE 1.85% 07/27 OATE                   8.540000e+07
# OAT 2.5% 09/26 OAT                        2.012600e+08
# OAT 2.75% 02/29 OAT                       2.500000e+08
# BELGIUM 5.50% 03/28                       4.674599e+06
# US TII 0.375% 7/25                        3.555900e+07
# OAT 1.5% 05/50                            1.395600e+08
# BTPSH 0% 2/33                             1.999455e+06
# OAT 3% 11/34 OAT                          7.303000e+07
# US TSY 2.75% 02/28                        4.835000e+07
# EFSF 1.75% 07/53                          6.061602e+07
# OAT 2.75% 02/30 OAT                       7.000000e+07
# TF FRN 10/25                              5.017500e+07
# US TSY 3.875% 11/27                       5.056500e+07
# SPGB IE 2.05% 11/39 SPGBE                 2.000000e+06
# EU 3.375% 4/38                            2.176000e+07
# AUSTRIA 4.15% 03/37                       2.112320e+07
# OAT 2.75% 02/29 OAT                       9.796000e+07
# OAT 6% 94-10/25                           7.424000e+07
# ESM 1.8% 11/46                            3.559056e+07
# SPAIN 3.25% 04/34                         2.000000e+06
# OAT 2.75% 10/27                           2.071250e+08
# BTPS IE 0.4% 05/30 BTPE                   2.435399e+06
# OAT I 3.40% 25/07/29 OATI                 4.500000e+07
# OAT % 11/29 OAT                           5.801900e+07
# OAT 0.75% 02/28 OAT                       1.901600e+08
# SFILFR 3.125% 09/29 EMTN                  1.012600e+07
# OAT % 11/29 OAT                           8.000000e+07
# OAT 2.75% 02/29 OAT                       1.023300e+08
# DBR 1% 05/38                              6.839000e+07
# OAT 1.25% 05/34 OAT                       1.920000e+07
# OAT 2.75% 10/27                           1.009400e+08
# EIB 4% 04/30                              6.447860e+07
# OAT 6% 94-10/25                           3.800000e+07
# SPAIN 3.9% 07/39                          2.000000e+06
# OAT 3% 11/34 OAT                          9.990000e+07
# OAT 3.25% 05/55 OAT                       4.000000e+07
# SPAIN 2.5% 05/27                          2.000000e+06
#
#                                                              counterparty name  \
# FINLAND 0.5% 09/28 10Y                                 HSBC CONTINENTAL EUROPE
# BTPS 1.6% 06/2026                         BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 3.50% 04/26                                                    BNP PARIBAS
# OAT 0.75% 05/53 OAT                                                BNP PARIBAS
# SPAIN % 05/25                                          HSBC CONTINENTAL EUROPE
# OAT I 0.1% 3/25 OATI                                         LA BANQUE POSTALE
# OAT 2.5% 5/30                                                      BNP PARIBAS
# BTPS IE 2.55% 09/41 BTPE                  BANCO BILBAO VISCAYA ARGENTARIA - ES
# OBL 2.4% 10/28 188                                           LA BANQUE POSTALE
# WFC 1.625% 06/25                                             LA BANQUE POSTALE
# OAT IE 0.1% 03/29 OATE                                       LA BANQUE POSTALE
# OAT I 3.40% 25/07/29 OATI                                    LA BANQUE POSTALE
# SPAIN 0% STRIP 10/34                      BANCO BILBAO VISCAYA ARGENTARIA - ES
# EU 4% 04/44 NGEU                                             LA BANQUE POSTALE
# EU 3.375% 10/39 NGEU                                 UNICREDIT BANK AG MUNCHEN
# CAISSE FRANCAISE DE F 3.24% 19/02/29 EUR                     LA BANQUE POSTALE
# CAFFIL 3.5% 03/29 EMTN                                       LA BANQUE POSTALE
# EFSF 1.45% 9/40                           BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 0.75% 05/53 OAT                                                BNP PARIBAS
# AUSTRIA 0.5% 02/29                                     HSBC CONTINENTAL EUROPE
# OAT 0% 02/27                                                           NATIXIS
# OAT 2.5% 09/27 OAT                                                 BNP PARIBAS
# BTPS 3.1% 08/26 2Y                                            SOCIETE GENERALE
# OAT 0.75% 11/28 OAT                                                BNP PARIBAS
# OAT IE 1.85% 07/27 OATE                                      LA BANQUE POSTALE
# OAT 0.75% 05/28                                              LA BANQUE POSTALE
# EIB 4% 04/30                              BANCO BILBAO VISCAYA ARGENTARIA - ES
# SPAIN 0% STRIP 10/30                      BANCO BILBAO VISCAYA ARGENTARIA - ES
# EFSF 1.7% 2/43                            BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 3% 05/33 OAT                                                   BNP PARIBAS
# SPAIN 0% STRIP 07/31 CAC                  BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 0.5% 05/29 OAT                                           LA BANQUE POSTALE
# TF FRN 01/26                                                  SOCIETE GENERALE
# SFILFR 2.875% 01/31 EMTN                                     LA BANQUE POSTALE
# OAT IE 1.85% 07/27 OATE                                      LA BANQUE POSTALE
# DBR 1% 05/38                                           HSBC CONTINENTAL EUROPE
# SPAIN 0% STRIP 10/32                      BANCO BILBAO VISCAYA ARGENTARIA - ES
# CAFFIL 2.875% 01/30 EMTN                                     LA BANQUE POSTALE
# US TII 0.375% 1/27                        BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 3% 05/33 OAT                                             LA BANQUE POSTALE
# DEXGRP 1% 10/27                                              LA BANQUE POSTALE
# OAT 3.50% 04/26                                                    BNP PARIBAS
# NEDERLD 0.5% 15/07/26                                        LA BANQUE POSTALE
# OAT 0.75% 11/28 OAT                                                BNP PARIBAS
# OAT 0.5% 05/29 OAT                                           LA BANQUE POSTALE
# TII 1.75% 01/34                           BANCO BILBAO VISCAYA ARGENTARIA - ES
# SPAIN 1.45% 10/71                                      HSBC CONTINENTAL EUROPE
# SPAIN 0% STRIP 10/31                      BANCO BILBAO VISCAYA ARGENTARIA - ES
# DBR 2.6% 05/41                                         HSBC CONTINENTAL EUROPE
# US TII 0.125% 7/26                        BANCO BILBAO VISCAYA ARGENTARIA - ES
# BTPS 2.1% 07/26 7Y                        BANCO BILBAO VISCAYA ARGENTARIA - ES
# EU 2.125% 08/40 EMTN                                 UNICREDIT BANK AG MUNCHEN
# TF FRN 10/25                                                  SOCIETE GENERALE
# BTPS 2.1% 07/26 7Y                        BANCO BILBAO VISCAYA ARGENTARIA - ES
# US TSY 3.875% 11/27                                           SOCIETE GENERALE
# OAT 3.50% 04/26                                                    BNP PARIBAS
# OAT 0.75% 11/28 OAT                                          LA BANQUE POSTALE
# BTP STRIP 01/08/33                        BANCO BILBAO VISCAYA ARGENTARIA - ES
# EU 3.25% 02/50 NGEU                                  UNICREDIT BANK AG MUNCHEN
# BTPSH 0% 2/33                             BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 5.50% 97-04/29                                           LA BANQUE POSTALE
# OAT 3.25% 05/55 OAT                                                BNP PARIBAS
# DBR % 08/50                                            HSBC CONTINENTAL EUROPE
# EFSF 1.75% 07/53                          BANCO BILBAO VISCAYA ARGENTARIA - ES
# EFSF 1.8% 07/48                           BANCO BILBAO VISCAYA ARGENTARIA - ES
# EFSF 2% 2/56                              BANCO BILBAO VISCAYA ARGENTARIA - ES
# BTPS 1.6% 06/2026                         BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 2.75% 02/30 OAT                                    HSBC CONTINENTAL EUROPE
# US TII 0.375% 7/25                                       BRED BANQUE POPULAIRE
# BTPS IE 0.4% 05/30 BTPE                   BANCO BILBAO VISCAYA ARGENTARIA - ES
# BTP STRIP 01/08/33                        BANCO BILBAO VISCAYA ARGENTARIA - ES
# BTPS IE 2.55% 09/41 BTPE                  BANCO BILBAO VISCAYA ARGENTARIA - ES
# DBR 2.3% 02/33                                         HSBC CONTINENTAL EUROPE
# BELGIUM 1% 06/26                                       HSBC CONTINENTAL EUROPE
# OAT I 0.1% 03/28 OATI                                        LA BANQUE POSTALE
# SPAIN 0% STRIP 10/29                      BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 6% 94-10/25                                              LA BANQUE POSTALE
# OAT 0.75% 05/28                                                    BNP PARIBAS
# NEDERLD 0.75% 07/28                                    HSBC CONTINENTAL EUROPE
# OAT I 3.40% 25/07/29 OATI                                    LA BANQUE POSTALE
# OAT IE 1.85% 07/27 OATE                                                NATIXIS
# OAT 2.5% 09/26 OAT                                                 BNP PARIBAS
# OAT 2.75% 02/29 OAT                                                BNP PARIBAS
# BELGIUM 5.50% 03/28                                          LA BANQUE POSTALE
# US TII 0.375% 7/25                                       BRED BANQUE POPULAIRE
# OAT 1.5% 05/50                                                     BNP PARIBAS
# BTPSH 0% 2/33                             BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 3% 11/34 OAT                                                   BNP PARIBAS
# US TSY 2.75% 02/28                                            SOCIETE GENERALE
# EFSF 1.75% 07/53                          BANCO BILBAO VISCAYA ARGENTARIA - ES
# OAT 2.75% 02/30 OAT                                    HSBC CONTINENTAL EUROPE
# TF FRN 10/25                                                  SOCIETE GENERALE
# US TSY 3.875% 11/27                                           SOCIETE GENERALE
# SPGB IE 2.05% 11/39 SPGBE                              HSBC CONTINENTAL EUROPE
# EU 3.375% 4/38                                               LA BANQUE POSTALE
# AUSTRIA 4.15% 03/37                                          LA BANQUE POSTALE
# OAT 2.75% 02/29 OAT                                    HSBC CONTINENTAL EUROPE
# OAT 6% 94-10/25                                              LA BANQUE POSTALE
# ESM 1.8% 11/46                            BANCO BILBAO VISCAYA ARGENTARIA - ES
# SPAIN 3.25% 04/34                                      HSBC CONTINENTAL EUROPE
# OAT 2.75% 10/27                                              LA BANQUE POSTALE
# BTPS IE 0.4% 05/30 BTPE                   BANCO BILBAO VISCAYA ARGENTARIA - ES
# OA
# OAT 0.75% 11/28 OAT                               125069
# BTP STRIP 01/08/33                                   187
# EU 3.25% 02/50 NGEU                               140502
# BTPSH 0% 2/33                                        187
# OAT 5.50% 97-04/29                                125069
# OAT 3.25% 05/55 OAT                                  254
# DBR % 08/50                                          374
# EFSF 1.75% 07/53                                     187
# EFSF 1.8% 07/48                                      187
# EFSF 2% 2/56                                         187
# BTPS 1.6% 06/2026                                    187
# OAT 2.75% 02/30 OAT                                  374
# US TII 0.375% 7/25                                   282
# BTPS IE 0.4% 05/30 BTPE                              187
# BTP STRIP 01/08/33                                   187
# BTPS IE 2.55% 09/41 BTPE                             187
# DBR 2.3% 02/33                                       374
# BELGIUM 1% 06/26                                     374
# OAT I 0.1% 03/28 OATI                             125069
# SPAIN 0% STRIP 10/29                                 187
# OAT 6% 94-10/25                                   125069
# OAT 0.75% 05/28                                      254
# NEDERLD 0.75% 07/28                                  374
# OAT I 3.40% 25/07/29 OATI                         125069
# OAT IE 1.85% 07/27 OATE                             6127
# OAT 2.5% 09/26 OAT                                   254
# OAT 2.75% 02/29 OAT                                  254
# BELGIUM 5.50% 03/28                               125069
# US TII 0.375% 7/25                                   282
# OAT 1.5% 05/50                                       254
# BTPSH 0% 2/33                                        187
# OAT 3% 11/34 OAT                                     254
# US TSY 2.75% 02/28                                  1882
# EFSF 1.75% 07/53                                     187
# OAT 2.75% 02/30 OAT                                  374
# TF FRN 10/25                                        1882
# US TSY 3.875% 11/27                                 1882
# SPGB IE 2.05% 11/39 SPGBE                            374
# EU 3.375% 4/38                                    125069
# AUSTRIA 4.15% 03/37                               125069
# OAT 2.75% 02/29 OAT                                  374
# OAT 6% 94-10/25                                   125069
# ESM 1.8% 11/46                                       187
# SPAIN 3.25% 04/34                                    374
# OAT 2.75% 10/27                                   125069
# BTPS IE 0.4% 05/30 BTPE                              187
# OAT I 3.40% 25/07/29 OATI                         125069
# OAT % 11/29 OAT                                   125069
# OAT 0.75% 02/28 OAT                                  254
# SFILFR 3.125% 09/29 EMTN                          125069
# OAT % 11/29 OAT                                   125069
# OAT 2.75% 02/29 OAT                                  254
# DBR 1% 05/38                                         374
# OAT 1.25% 05/34 OAT                               125069
# OAT 2.75% 10/27                                      254
# EIB 4% 04/30                                         187
# OAT 6% 94-10/25                                   125069
# SPAIN 3.9% 07/39                                     374
# OAT 3% 11/34 OAT                                     254
# OAT 3.25% 05/55 OAT                                  254
# SPAIN 2.5% 05/27                                     374

# %%
# list of swaps SOFR
j=0
pdswap = pd.DataFrame(columns=col)
for i in range(len(dd)):
    if ((dd[i]['assetType']=='SWAP_ON_RATE') and ("SOFR" in dd[i]['name'])):
        j=j+1
        pdnew=pd.DataFrame([[dd[i]['maturityDate'],
                             dd[i]['quotations'][0]['date'],
                             dd[i]['quotations'][0]['close'],
                             dd[i]['legs'][0]['side'], 
                             dd[i]['legs'][0]['interest']['rateType'], 
                             dd[i]['legs'][0]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][0]['interest']['dayCountMethod'], 
                             dd[i]['legs'][0]['interest']['index']['_id'], 
                             dd[i]['legs'][1]['side'], 
                             dd[i]['legs'][1]['interest']['rateType'], 
                             dd[i]['legs'][1]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][1]['interest']['dayCountMethod'],
                             dd[i]['legs'][1]['interest'].get('rate')
                            ]], 
                             columns=col, index=[dd[i]['name']])
        pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
print(j)
pdswap
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~/.local/share/virtualenvs/swap-v_L5ymoK/lib/python3.12/site-packages/pandas/core/internals/construction.py:939, in _finalize_columns_and_data(content, columns, dtype)
#     938 try:
# --> 939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
#
# File ~/.local/share/virtualenvs/swap-v_L5ymoK/lib/python3.12/site-packages/pandas/core/internals/construction.py:986, in _validate_or_indexify_columns(content, columns)
#     984 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#     985     # caller's responsibility to check for this...
# --> 986     raise AssertionError(
#     987         f"{len(columns)} columns passed, passed data had "
#     988         f"{len(content)} columns"
#     989     )
#     990 if is_mi_list:
#     991     # check if nested list column, length of each sub-list should be equal
#
# AssertionError: 6 columns passed, passed data had 11 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 7
#       5     if ((dd[i]['assetType']=='SWAP_ON_RATE') and ("SOFR" in dd[i]['name'])):
#       6         j=j+1
# ----> 7         pdnew=pd.DataFrame([[dd[i]['maturityDate'],
#       8                              dd[i]['quotations'][0]['date'],
#       9                              dd[i]['quotations'][0]['close'],
#      10                              dd[i]['legs'][0]['side'],
#      11                              dd[i]['legs'][0]['interest']['rateType'],
#      12                              dd[i]['legs'][0]['interest']['paymentFrequency']['code'],
#      13                              #dd[i]['legs'][0]['interest']['dayCountMethod'],
#      14                              dd[i]['legs'][0]['interest']['index']['_id'],
#      15                              dd[i]['legs'][1]['side'],
#      16                              dd[i]['legs'][1]['interest']['rateType'],
#      17                              dd[i]['legs'][1]['interest']['paymentFrequency']['code'],
#      18                              #dd[i]['legs'][1]['interest']['dayCountMethod'],
#      19                              dd[i]['legs'][1]['interest'].get('rate')
#      20                             ]],
#      21                              columns=col, index=[dd[i]['name']])
#      22         pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
#      23 print(j)
#
# File ~/.local/share/virtualenvs/swap-v_L5ymoK/lib/python3.12/site-packages/pandas/core/frame.py:851, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     849     if columns is not None:
#     850         columns = ensure_index(columns)
# --> 851     arrays, columns, index = nested_data_to_arrays(
#     852         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     853         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#     854         data,
#     855         columns,
#     856         index,  # type: ignore[arg-type]
#     857         dtype,
#     858     )
#     859     mgr = arrays_to_mgr(
#     860         arrays,
#     861         columns,
#    (...)
#     864         typ=manager,
#     865     )
#     866 else:
#
# File ~/.local/share/virtualenvs/swap-v_L5ymoK/lib/python3.12/site-packages/pandas/core/internals/construction.py:520, in nested_data_to_arrays(data, columns, index, dtype)
#     517 if is_named_tuple(data[0]) and columns is None:
#     518     columns = ensure_index(data[0]._fields)
# --> 520 arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521 columns = ensure_index(columns)
#     523 if index is None:
#
# File ~/.local/share/virtualenvs/swap-v_L5ymoK/lib/python3.12/site-packages/pandas/core/internals/construction.py:845, in to_arrays(data, columns, dtype)
#     842     data = [tuple(x) for x in data]
#     843     arr = _list_to_arrays(data)
# --> 845 content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846 return content, columns
#
# File ~/.local/share/virtualenvs/swap-v_L5ymoK/lib/python3.12/site-packages/pandas/core/internals/construction.py:942, in _finalize_columns_and_data(content, columns, dtype)
#     939     columns = _validate_or_indexify_columns(contents, columns)
#     940 except AssertionError as err:
#     941     # GH#26429 do not raise user-facing AssertionError
# --> 942     raise ValueError(err) from err
#     944 if len(contents) and contents[0].dtype == np.object_:
#     945     contents = convert_object_array(contents, dtype=dtype)
#
# ValueError: 6 columns passed, passed data had 11 columns

# %%
# list of swaps no SOFR and ESTR and EU
j=0
col=['maturityDate', 'quotationdate', 'quotationvalue', 'side0', 'ratetype', 'frequency',  'rate', 'side1','ratetype1','frequency',  'index' ] 
#col=['maturityDate', 'side0', 'ratetype', 'frequency', 'daycountmethod' ,'index','ratetype1','frequency', 'daycountmethod', 'rate'] #

pdswap = pd.DataFrame(columns=col)
for i in range(len(dd)):
    if ((dd[i]['assetType']=='SWAP_ON_RATE') and ("SOFR" not in dd[i]['name']) and ("_ESTR" not in dd[i]['name'])and ("EUR" not in dd[i]['name'])):
        j=j+1
        pdnew=pd.DataFrame([[dd[i]['maturityDate'],
                             dd[i]['quotations'][0]['date'],
                             dd[i]['quotations'][0]['close'],
                             dd[i]['legs'][0]['side'], 
                             dd[i]['legs'][0]['interest']['rateType'], 
                             dd[i]['legs'][0]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][0]['interest']['dayCountMethod'], 
                             #dd[i]['legs'][0]['interest']['index']['_id'], 
                             dd[i]['legs'][0]['interest'].get('rate'),
                             dd[i]['legs'][1]['side'], 
                             dd[i]['legs'][1]['interest']['rateType'], 
                             dd[i]['legs'][1]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][1]['interest']['dayCountMethod'],
                             dd[i]['legs'][1]['interest']['index']['_id'], 
                            ]], 
                             columns=col, index=[dd[i]['name']])        
        pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
print(j)
pdswap

# %%
# list of swaps no SOFR and ESTR and EU
j=0
col=['maturityDate', 'quotationdate', 'quotationvalue', 'side0', 'ratetype', 'frequency', 'index', 'side1','ratetype1','frequency','rate' ] 
#col=['maturityDate', 'side0', 'ratetype', 'frequency', 'daycountmethod' ,'index','ratetype1','frequency', 'daycountmethod', 'rate'] #

pdswap = pd.DataFrame(columns=col)
for i in range(len(dd)):
    if ((dd[i]['assetType']=='SWAP_ON_RATE') and ("SOFR" not in dd[i]['name']) and ("_ESTR" not in dd[i]['name'])and ("EUR"  in dd[i]['name'])):
        j=j+1
        pdnew=pd.DataFrame([[dd[i]['maturityDate'],
                             dd[i]['quotations'][0]['date'],
                             dd[i]['quotations'][0]['close'],
                             dd[i]['legs'][0]['side'], 
                             dd[i]['legs'][0]['interest']['rateType'], 
                             dd[i]['legs'][0]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][0]['interest']['dayCountMethod'], 
                             dd[i]['legs'][0]['interest']['index']['_id'], 
                             dd[i]['legs'][1]['side'], 
                             dd[i]['legs'][1]['interest']['rateType'], 
                             #dd[i]['legs'][1]['interest']['paymentFrequency']['code'], 
                             dd[i]['legs'][1]['interest']['dayCountMethod'],
                             dd[i]['legs'][1]['interest'].get('rate'),
                            ]], 
                             columns=col, index=[dd[i]['name']])        
        pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
print(j)
pdswap

# %%
# index
j=0
col=['index' , 'assetType', 'dates', 'last', 'currency'] 
#col=['maturityDate', 'side0', 'ratetype', 'frequency', 'daycountmethod' ,'index','ratetype1','frequency', 'daycountmethod', 'rate'] #

pdswap = pd.DataFrame(columns=col)
for i in range(len(dd)):
    if ((dd[i]['_id']=='251377')or (dd[i]['_id']=='6741831')or (dd[i]['_id']=='549433')or (dd[i]['_id']=='5967593')or (dd[i]['_id']=='6741831')):
        j=j+1
        pdnew=pd.DataFrame([[dd[i]['_id'],
                             dd[i]['assetType'], 
                             dd[i]['quotations'][0]['date'], 
                             dd[i]['quotations'][0]['last'], 
                             dd[i]['ccy']
                             #dd[i]['legs'][0]['interest']['index']['_id'], 
                             #dd[i]['legs'][1]['side'], 
                             #dd[i]['legs'][1]['interest']['rateType'], 
                             #dd[i]['legs'][1]['interest']['paymentFrequency']['code'], 
                             #dd[i]['legs'][1]['interest']['dayCountMethod'],
                             #dd[i]['legs'][1]['interest'].get('rate'),
                            ]], 
                             columns=col, index=[dd[i]['name']])        
        pdswap = pd.concat([pdswap, pdnew], ignore_index=False)
        #print(dd[i])
print(j)
pdswap
